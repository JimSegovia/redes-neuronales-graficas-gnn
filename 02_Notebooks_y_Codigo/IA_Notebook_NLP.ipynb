# %%
# 1. Identificar la versión de PyTorch instalada en Colab
import torch
print(f"Versión de PyTorch: {torch.__version__}")

# 2. Instalar las dependencias de PyG indexadas para esa versión específica
# !pip install torch-scatter torch-sparse -f https://data.pyg.org/whl/torch-{torch.__version__}.html
# !pip install torch-geometric

# 3. Verificar que la instalación fue exitosa
import torch_geometric
print(f"Versión de PyTorch Geometric: {torch_geometric.__version__}")
